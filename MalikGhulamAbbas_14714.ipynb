# %% [markdown]
# <a href="https://colab.research.google.com/github/Malik14714/AI_Assignment/blob/main/MalikGhulamAbbas_14714.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #import the numpy library and assigned with the name of np
import matplotlib.pyplot as plt #import matplotlib and assigned with the name of plt

# %%
width = 0.2

# %%
x1 = np.arange(len(models))
x2 = [x + width for x in x1]
x3 = [x + width for x in x2]

# %%
models = ["BiGRU", "LSTM", "SDAE-LSTM", "SDAE-GRU", "SDAE-BiGRU", "SDAE-BiLSTM", "Ensemble"]
rmse = [0.0633, 0.0629, 0.0646, 0.0655, 0.0629, 0.064, 0.0194]
mae = [0.0463, 0.0453, 0.0462, 0.0466, 0.0450, 0.0457, 0.0149]
mse = [0.0040, 0.0039, 0.0041, 0.0043, 0.0039, 0.0041, 0.0003]

# %%
plt.figure(figsize=(10, 15))

# %%
plt.xlabel("Machine Learning Models") #show the xlabel in machine learning 
plt.ylabel("Evalution Measures") #show the xlabel in Evalution Measures
plt.title("Comparative Analysis for cluster ID C0M1") #show the xlabel in Comparative Anaylsus
plt.xticks(x2, models, rotation=45)
plt.xticks(x2, models)
plt.legend(loc="upper right", bbox_to_anchor=(1.25, 1)) #show the measurmennt of the model
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.bar(x1, rmse, width=width, color="#f5ebe0", label="RMSE")
plt.bar(x2, mae, width=width, color="#264653", label="MAE")
plt.bar(x3, mse, width=width, color="#8338ec", label="MSE")
# Out:
# <BarContainer object of 7 artists>

# %%
plt.show()
