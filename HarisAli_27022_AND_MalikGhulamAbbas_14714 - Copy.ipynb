# %%
import pandas as pd #Import pandas library and assign with the name of "pd"
import numpy as np #Import numpy library and assign with the name of "np"
import datetime as dt #Import date & time library and assign with the name of "dt"
train = pd.read_csv('train.csv') #Read the contents in "train.csv" and store in pandas DataFrame called "train"
test = pd.read_csv('test.csv') #Read the contents in "test.csv" and store in pandas DataFrame called "test"

# %%
train
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe31003300320037003900      2008-03-10  Female      Product
# 3      fffe32003400380032003900      2008-11-03    Male      Service
# 4      fffe31003900340031003600      2008-07-24  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      2008-12-30  Female      Service
# 22746  fffe33003000350031003800      2008-01-19  Female      Product
# 22747          fffe390032003000      2008-11-05    Male      Service
# 22748  fffe33003300320036003900      2008-01-10  Female      Service
# 22749      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  3.0
# ...

# %%
train.describe() #Calculate the descriptive statistics of "train" DataFrame
# Out:
#         Designation  Resource Allocation  Mental Fatigue Score     Burn Rate
# count  22750.000000         21369.000000          20633.000000  21626.000000
# mean       2.178725             4.481398              5.728188      0.452005
# std        1.135145             2.047211              1.920839      0.198226
# min        0.000000             1.000000              0.000000      0.000000
# 25%        1.000000             3.000000              4.600000      0.310000
# 50%        2.000000             4.000000              5.900000      0.450000
# 75%        3.000000             6.000000              7.100000      0.590000
# max        5.000000            10.000000             10.000000      1.000000

# %%
import seaborn as sns #Import seaborn library and assign with the name of "sns"
import matplotlib.pyplot as plt #Import pyplot library from matplotlib and assign with the name of "plt"
plt.figure(figsize = (10,6)) #Create a new figure object with size of 10 inches width & 6 inches height
sns.boxplot(train['Burn Rate']) #Distribute the the values in "Burn Rate" which is the coloumn of "train" DataFrame
plt.title('Burn Rate') #Set the title of plot to "Burn Rate using" title method
plt.show #Display the plot on the screen
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
train['Date of Joining'] = pd.to_datetime(train['Date of Joining']) #Converts the "Date of Joining" column in the "train" DataFrame from its current format
train
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe31003300320037003900      2008-03-10  Female      Product
# 3      fffe32003400380032003900      2008-11-03    Male      Service
# 4      fffe31003900340031003600      2008-07-24  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      2008-12-30  Female      Service
# 22746  fffe33003000350031003800      2008-01-19  Female      Product
# 22747          fffe390032003000      2008-11-05    Male      Service
# 22748  fffe33003300320036003900      2008-01-10  Female      Service
# 22749      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  3.0
# ...

# %%
def get_y_m_d(train): #Define a function named with "get_y_m_d" train datatime as input
    train['Years'] = train['Date of Joining'].dt.year #Creates a new column called "Years" in train DataFrame using dt assign values
    train['Months'] = train['Date of Joining'].dt.month #Creates a new column called "Months" in train DataFrame using dt assign val
    train['Date'] = train['Date of Joining'].dt.day #Creates a new column called "Date" in train DataFrame using dt assign val
    return train 
train = get_y_m_d(train) #Calls the function and assigned the return DataFrame
train.drop(columns =['Date of Joining'],inplace = True) #Drop the columns of "Date of Joining" from train DataFrame
train
# Out:
#                     Employee ID  Gender Company Type WFH Setup Available  \
# 0      fffe32003000360033003200  Female      Service                  No
# 1          fffe3700360033003500    Male      Service                 Yes
# 2      fffe31003300320037003900  Female      Product                 Yes
# 3      fffe32003400380032003900    Male      Service                 Yes
# 4      fffe31003900340031003600  Female      Service                  No
# ...                         ...     ...          ...                 ...
# 22745  fffe31003500370039003100  Female      Service                  No
# 22746  fffe33003000350031003800  Female      Product                 Yes
# 22747          fffe390032003000    Male      Service                 Yes
# 22748  fffe33003300320036003900  Female      Service                  No
# 22749      fffe3400350031003800    Male      Product                  No
#
#        Designation  Resource Allocation  Mental Fatigue Score  Burn Rate  \
# ...

# %%
train['Company Type'].value_counts() #Calculate the each unqiue value in Company type column
# Out:
# Service    14833
# Product     7917
# Name: Company Type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder #import the labelEncoder from sklearn.preprocessing module
lab_enc = LabelEncoder() #create the instance and assigned it with "lab_enc"
train['Gender']=lab_enc.fit_transform(train['Gender']) #Encodes the "Gender" column in train DataFrame and fit with "lab_enc" variable
train['Company Type']=lab_enc.fit_transform(train['Company Type']) #Encodes the "Company Name" column in train DataFrame and fit with "lab_enc" variable
train['WFH Setup Available']=lab_enc.fit_transform(train['WFH Setup Available']) #Encodes the "WFH Setup Available" column in train DataFrame and fit with "lab_enc" variable
train #show the contents in the train DataFrame
# Out:
#                     Employee ID  Gender  Company Type  WFH Setup Available  \
# 0      fffe32003000360033003200       0             1                    0
# 1          fffe3700360033003500       1             1                    1
# 2      fffe31003300320037003900       0             0                    1
# 3      fffe32003400380032003900       1             1                    1
# 4      fffe31003900340031003600       0             1                    0
# ...                         ...     ...           ...                  ...
# 22745  fffe31003500370039003100       0             1                    0
# 22746  fffe33003000350031003800       0             0                    1
# 22747          fffe390032003000       1             1                    1
# 22748  fffe33003300320036003900       0             1                    0
# 22749      fffe3400350031003800       1             0                    0
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22750 entries, 0 to 22749
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Employee ID           22750 non-null  object
#  1   Gender                22750 non-null  int64
#  2   Company Type          22750 non-null  int64
#  3   WFH Setup Available   22750 non-null  int64
#  4   Designation           22750 non-null  float64
#  5   Resource Allocation   21369 non-null  float64
#  6   Mental Fatigue Score  20633 non-null  float64
#  7   Burn Rate             21626 non-null  float64
#  8   Years                 22750 non-null  int64
#  9   Months                22750 non-null  int64
#  10  Date                  22750 non-null  int64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 1.9+ MB
